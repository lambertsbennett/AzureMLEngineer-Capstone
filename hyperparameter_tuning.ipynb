# %% [markdown]
# # Hyperparameter Tuning using HyperDrive

# %%
import os

from azureml.core import Workspace, Experiment

from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# %% [markdown]
# ## Dataset
#
# TODO: Get data. In the cell below, write code to access the data you will be using in this project. Remember that the dataset needs to be external.

# %%
ws = Workspace.from_config()
experiment_name = 'capstone-hd'

experiment = Experiment(ws, experiment_name)

# Retrieve data from datasets
key = "cc-fraud"
description_text = "Credit card fraud dataset from Kaggle."

try:
    dataset = ws.datasets[key]
except:
    print("Dataset not found in Azure datasets.")
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code FVEAR2KXQ to authenticate.
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.

# %%
amlcompute_cluster_name = "capstone"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# Out:
# Creating
# Succeeded...............................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Hyperdrive Configuration
#
# TODO: Explain the model you are using and the reason for chosing the different hyperparameters, termination policy and config settings.

# %%
from azureml.core import Environment

sklearn_env = Environment.from_conda_specification(name='sklearn-env', file_path='./conda_dependencies.yml')

# %%
from azureml.core import ScriptRunConfig
from azureml.train.hyperdrive.run import PrimaryMetricGoal
from azureml.train.hyperdrive.policy import BanditPolicy
from azureml.train.hyperdrive.sampling import RandomParameterSampling
from azureml.train.hyperdrive.runconfig import HyperDriveConfig 
from azureml.train.hyperdrive.parameter_expressions import quniform

src = ScriptRunConfig(source_directory=".",
                        script='train.py',
                        arguments=['--input_data', dataset.as_named_input('ccfraud')],
                        compute_target=compute_target,
                        environment=sklearn_env)

early_termination_policy = BanditPolicy(slack_factor=0.2, evaluation_interval=1, delay_evaluation=5)

param_sampling = RandomParameterSampling({
    "--n_estimators": quniform(10,1000,1),
    "--max_depth": quniform(0,100,1) })


hyperdrive_run_config = HyperDriveConfig(run_config=src,
    hyperparameter_sampling=param_sampling,
    policy=early_termination_policy,
    primary_metric_name="auc",
    primary_metric_goal=PrimaryMetricGoal.MAXIMIZE,
    max_total_runs=20,
    max_concurrent_runs=4)

# %%
hyperdrive_run = experiment.submit(hyperdrive_run_config)

# %% [markdown]
# ## Run Details
#
# OPTIONAL: Write about the different models trained and their performance. Why do you think some models did better than others?
#
# TODO: In the cell below, use the `RunDetails` widget to show the different experiments.

# %%
from azureml.widgets import RunDetails
RunDetails(hyperdrive_run).show()
# Out:
# _HyperDriveWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO'…

# %% [markdown]
# ## Best Model
#
# TODO: In the cell below, get the best model from the hyperdrive experiments and display all the properties of the model.

# %%
best_run = hyperdrive_run.get_best_run_by_primary_metric()
best_run.get_details()
# Out:
# {'runId': 'HD_9ef1ab88-ef97-405b-9058-324712c05b24_23',
#  'target': 'capstone',
#  'status': 'Completed',
#  'startTimeUtc': '2021-02-14T20:10:58.122634Z',
#  'endTimeUtc': '2021-02-14T20:13:55.620207Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'abdcbe5d-bb33-48f9-ba10-6d7ae45d853b',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': '805a1857-c06d-4241-b0b0-910fc275b00c'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'ccfraud', 'mechanism': 'Direct'}}, {'dataset': {'id': '805a1857-c06d-4241-b0b0-910fc275b00c'}, 'consumptionDetails': {'type': 'Reference'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--input_data',
#    'DatasetConsumptionConfig:ccfraud',
#    '--max_depth',
#    '9',
#    '--n_estimators',
#    '133'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'capstone',
#   'dataReferences': {},
#   'data': {'ccfraud': {'dataLocation': {'dataset': {'id': '805a1857-c06d-4241-b0b0-910fc275b00c',
#       'name': 'cc-fraud',
#       'version': '1'},
#      'dataPath': None},
#     'mechanism': 'Direct',
#     'environmentVariableName': 'ccfraud',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'sklearn-env',
#    'version': 'Autosave_2021-02-14T18:06:22Z_ef6a1dd2',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'dependencies': ['python=3.6.2',
#       'scikit-learn',
#       'pandas',
#       {'pip': ['azureml-defaults', 'packaging']}],
#      'name': 'azureml_9ec041b1b9a2cda6cab5efb73baf62c9'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'frameworkImage': None,
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': None, 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_5567177693a602cd2be16c5cc01633c24cce295a789ac361480543af8edb0ebf_d.txt': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/azureml-logs/55_azureml-execution-tvmps_5567177693a602cd2be16c5cc01633c24cce295a789ac361480543af8edb0ebf_d.txt?sv=2019-02-02&sr=b&sig=hirQRUO%2FIe0rvH0vGHMmzd3Z59GF%2FbjgHicP1paWhfo%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_5567177693a602cd2be16c5cc01633c24cce295a789ac361480543af8edb0ebf_d.txt': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/azureml-logs/65_job_prep-tvmps_5567177693a602cd2be16c5cc01633c24cce295a789ac361480543af8edb0ebf_d.txt?sv=2019-02-02&sr=b&sig=HA156oCcxEuFDTVduIQbCq2CTEpYYyiaPCsKthNqw%2FE%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=3nzrFF6Cd87QD%2Fh56K0fFf1njof7nswcOovmrm81NG4%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_5567177693a602cd2be16c5cc01633c24cce295a789ac361480543af8edb0ebf_d.txt': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/azureml-logs/75_job_post-tvmps_5567177693a602cd2be16c5cc01633c24cce295a789ac361480543af8edb0ebf_d.txt?sv=2019-02-02&sr=b&sig=NSr322AVumRobgI4%2BkjTILQpWWIblk3LVa9O9q0QNrs%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r',
#   'azureml-logs/process_info.json': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=I%2FQdYrQRLrDBle35y%2F1K8uqdAgP8ZxtgEze0lgsuWmY%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r',
#   'azureml-logs/process_status.json': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=qAHsyznZ%2FVaKITgOOJgAnbSRID77l0cgfdswXB5EviY%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r',
#   'logs/azureml/101_azureml.log': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/logs/azureml/101_azureml.log?sv=2019-02-02&sr=b&sig=NoP7WRBORRRWMpltYWoWH8VDiEDtcV5%2B8ctewuy0kzk%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=dzANFqg2%2BGrc36VSI5AOpubYX1I4AmksE0AZ%2FxjzSVA%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=pzO6UxCnpJTA6mFktTYkq%2FPOnKZP4RX5WXi5TvNfv4w%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=eRtH84NWJTrVNSYJ94p351HF6S1Jy42Xmj5ty%2FGhdtQ%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://mlstrg138901.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_9ef1ab88-ef97-405b-9058-324712c05b24_23/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=50jOUrUuJpvY8428ByF1vJStxapbTY0khpxx4Fa1KIw%3D&st=2021-02-14T20%3A30%3A13Z&se=2021-02-15T04%3A40%3A13Z&sp=r'},
#  'submittedBy': 'ODL_User 138901'}
